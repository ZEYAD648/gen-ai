# %% [markdown]
# <a href="https://colab.research.google.com/github/ZEYAD648/gen-ai/blob/main/LEARN%20PY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word =["whats","your","name"]
result =" ".join(word)
print(result)
# Out:
# whats your name

# %%
q="whats your name"
words = q.split()
print(words)
# Out:
# ['whats', 'your', 'name']

# %%
text ="i love en"
print (text.replace("en","ar"))
# Out:
# i love ar

# %%
text ="HELLO"
print (text.lower())
# Out:
# hello

# %%
t="       hello"
print (t.strip())
# Out:
# hello

# %%
w= "hello"
print(len(text))
# Out:
# 5

# %%
token =["ko","co","wo"]
print (len(token))
# Out:
# 3

# %%
text =["zozo","mezo","dodo"]
print(text[-1])
# Out:
# dodo

# %%
print (type(6))
# Out:
# <class 'int'>

# %%
n =[1,2,3,4]
print(sum(n))
#sum max min len type join split دوال بيلت
# Out:
# 10

# %%
q = input("enter q: ")

def route(q):
    if "weather" in q:

        return "weather tool"
    elif "email" in q:
        return "email tool"
    else:
        return "llm"

# استدعاء الدالة لرؤية النتيجة
print(route(q))
# Out:
# enter q: h
# llm

# %%
import json

user = {"name": "ahmed",
        "age": 20}
json_data = json.dumps(user)
print(json_data)
# العكس داله LOAD
# Out:
# {"name": "ahmed", "age": 20}
